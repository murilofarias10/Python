# %% [markdown]
# <a href="https://colab.research.google.com/github/murilofarias10/AnaliseComPython/blob/main/Analise_Exploratoria_airbnb_NewYork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Murilo Farias** Code:

# %%
import pandas as pd

# %%
import urllib

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base = pd.read_excel("/content/assinaturas.xlsx")

# %%
base.shape
# Out:
# (30, 7)

# %%
#Imprimindo cabeçalho
base.head()
# Out:
#         Username                      Nome  ... Assinatura Total_Gasto
# 0      Neave1959     Mrs Anna \t     Sharp  ... 2020-09-18       140.04
# 1  Nicterims1993    Mrs \tDaisy Anderson    ... 2021-01-29      2417.81
# 2   Fouldlairity          Ms Zoe \tPeacock  ... 2020-12-04        51.95
# 3   Ancomettiody    Mrs Libby \tWilliams    ... 2020-11-21       130.73
# 4         Onswis       Ms Katie \tMetcalfe  ... 2021-02-27      1778.72
#
# [5 rows x 7 columns]

# %%
#Verificando nome de todas as colunas
arquivo.columns
# Out:
# Index(['Username;Nome;Sexo;Data_Nascimento;Ocupação;Assinatura;Total_Gasto '], dtype='object')

# %%
#Alterando nome da coluna
base_nova = base.rename(columns={'OcupaÃ§Ã£o': 'Ocupacao'})

# %%
base_nova['Nome'] = base_nova['Nome'].replace(' ', '')

# %%
base_nova['Ocupacao'].unique()
# Out:
# array(['Engenheiro de Dados', 'Analista Financeiro', 'EstatÃ\xadstico',
#        'Engenheiro de Machine Learning', 'Gerente de Tecnologia',
#        'Analista de InteligÃªncia de Mercado', 'Web Designer',
#        'Arquiteto de Dados', 'Analista de RH', 'Cientista de Dados',
#        'Desenvolvedor Java', 'Desenvolvedor de Chatbots',
#        'Engenheiro de InteligÃªncia Artificial',
#        'Especialista em Cloud Computing', 'Engenheiro ElÃ©trico'],
#       dtype=object)

# %%
#tratamnto de dados substituindo valores estranhos
base_nova['Ocupacao'] = base_nova['Ocupacao'].replace('EstatÃ\xadstico', 'Estatistico')

# %%
#tratamnto de dados substituindo valores estranhos
base_nova['Ocupacao'] = base_nova['Ocupacao'].replace('Analista de InteligÃªncia de Mercado', 'Analista de Inteligencia de Mercado')

# %%
base_nova['Ocupacao'] = base_nova['Ocupacao'].replace('Engenheiro de InteligÃªncia Artificial', 'Engenheiro de Inteligencia Artificial')

# %%
base_nova['Ocupacao'] = base_nova['Ocupacao'].replace('Engenheiro ElÃ©trico', 'Engenheiro Eletrico')

# %%
base_nova['Ocupacao'].unique()
# Out:
# array(['Engenheiro de Dados', 'Analista Financeiro', 'Estatistico',
#        'Engenheiro de Machine Learning', 'Gerente de Tecnologia',
#        'Analista de Inteligencia de Mercado', 'Web Designer',
#        'Arquiteto de Dados', 'Analista de RH', 'Cientista de Dados',
#        'Desenvolvedor Java', 'Desenvolvedor de Chatbots',
#        'Engenheiro de Inteligencia Artificial',
#        'Especialista em Cloud Computing', 'Engenheiro Eletrico'],
#       dtype=object)

# %%
base_nova['Ocupacao']
# Out:
# 0                       Engenheiro de Dados
# 1                       Engenheiro de Dados
# 2                       Analista Financeiro
# 3                               Estatistico
# 4            Engenheiro de Machine Learning
# 5                     Gerente de Tecnologia
# 6       Analista de Inteligencia de Mercado
# 7                              Web Designer
# 8       Analista de Inteligencia de Mercado
# 9                        Arquiteto de Dados
# 10                           Analista de RH
# 11                       Arquiteto de Dados
# 12                      Engenheiro de Dados
# 13                       Cientista de Dados
# 14                       Desenvolvedor Java
# 15                Desenvolvedor de Chatbots
# 16    Engenheiro de Inteligencia Artificial
# 17          Especialista em Cloud Computing
# 18                      Engenheiro Eletrico
# 19                      Engenheiro de Dados
# 20                       Arquiteto de Dados
# ...

# %%
base_nova.dtypes
# Out:
# Username                   object
# Nome                       object
# Sexo                       object
# Data_Nascimento    datetime64[ns]
# Ocupacao                   object
# Assinatura         datetime64[ns]
# Total_Gasto               float64
# dtype: object

# %%
base_nova = base_nova.rename(columns={'Total_Gasto ': 'Custo_Total'})

# %%
#verificando se existe alguma linha em branco
base_nova.isnull().sum()
# Out:
# Username           0
# Nome               0
# Sexo               0
# Data_Nascimento    0
# Ocupacao           0
# Assinatura         0
# Total_Gasto        0
# dtype: int64

# %%
custo = base_nova['Custo_Total'].sum()

print('O custo toral é: R$ {:.2f}'.format(custo))
# Out:
# O custo toral é: R$ 30626.09

# %%
sns.countplot(data=base_nova, x='Ocupacao')

# %%
base_nova.groupby(['Ocupacao']).Ocupacao.count()
# Out:
# Ocupacao
# Analista Financeiro                      1
# Analista de Inteligencia de Mercado      2
# Analista de RH                           1
# Arquiteto de Dados                       3
# Cientista de Dados                       8
# Desenvolvedor Java                       1
# Desenvolvedor de Chatbots                1
# Engenheiro Eletrico                      1
# Engenheiro de Dados                      6
# Engenheiro de Inteligencia Artificial    1
# Engenheiro de Machine Learning           1
# Especialista em Cloud Computing          1
# Estatistico                              1
# Gerente de Tecnologia                    1
# Web Designer                             1
# Name: Ocupacao, dtype: int64

# %%
base_nova['Custo_Total'].describe()
# Out:
# count      30.000000
# mean     1020.869667
# std       961.610211
# min        40.310000
# 25%       239.532500
# 50%       707.835000
# 75%      1313.657500
# max      3464.720000
# Name: Custo_Total, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.bar(base_nova['Ocupacao'], base_nova['Custo_Total'])


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e7182447720e> in <module>()
# ----> 1 plt.figure(figsize=(10, 6))
#       2 plt.bar(base_nova['Ocupacao'], base_nova['Custo_Total'])
#       3
#       4
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
##########################################################################################

# %%
arquivo = pd.read_csv('AB_NYC_2019.csv')

# %%
arquivo.shape
# Out:
# (48895, 16)

# %%
arquivo.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
arquivo.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
arquivo.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
arquivo.head(3)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 1  2595                Skylit Midtown Castle     2845   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %% [markdown]
# verificar quantas casas **em branco** temos na base de dados

# %%
arquivo.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# **apagando colunas descenessarias** para base de dados

# %%
dropcoluns = ['id', 'host_name', 'last_review']
arquivo.drop(dropcoluns, axis='columns', inplace=True)
arquivo.head()
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# ...

# %%
arquivo.shape
# Out:
# (48895, 13)

# %% [markdown]
# Vamos preencher linhas que estão com valor **NaN** e substituir por **0zero** na coluna reviews_per_month

# %%
arquivo.fillna({'reviews_per_month': 0}, inplace=True)
arquivo.head()
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# ...

# %%
arquivo.isnull().sum()
# Out:
# name                              16
# host_id                            0
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
arquivo.shape
# Out:
# (48895, 13)

# %% [markdown]
# Exemplo para filtrar apenas algumas colunas e algumas linhas...
# **Estamos trazendo apenas as 8 primeiras linhas de 3 colunas**

# %%
arquivo[0:8][['name','neighbourhood_group','price']]
# Out:
#                                                name neighbourhood_group  price
# 0                Clean & quiet apt home by the park            Brooklyn    149
# 1                             Skylit Midtown Castle           Manhattan    225
# 2               THE VILLAGE OF HARLEM....NEW YORK !           Manhattan    150
# 3                   Cozy Entire Floor of Brownstone            Brooklyn     89
# 4  Entire Apt: Spacious Studio/Loft by central park           Manhattan     80
# 5         Large Cozy 1 BR Apartment In Midtown East           Manhattan    200
# 6                                   BlissArtsSpace!            Brooklyn     60
# 7                  Large Furnished Room Near B'way            Manhattan     79

# %%
display(arquivo)
# Out:
#                                                     name    host_id  \
# 0                     Clean & quiet apt home by the park       2787
# 1                                  Skylit Midtown Castle       2845
# 2                    THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3                        Cozy Entire Floor of Brownstone       4869
# 4       Entire Apt: Spacious Studio/Loft by central park       7192
# 5              Large Cozy 1 BR Apartment In Midtown East       7322
# 6                                        BlissArtsSpace!       7356
# 7                       Large Furnished Room Near B'way        8967
# 8                     Cozy Clean Guest Room - Family Apt       7490
# 9                     Cute & Cozy Lower East Side 1 bdrm       7549
# 10                      Beautiful 1br on Upper West Side       7702
# 11                       Central Manhattan/near Broadway       7989
# 12        Lovely Room 1, Garden, Best Area, Legal rental       9744
# ...

# %%
arquivo.head()
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# ...

# %% [markdown]
# **Boolean indexing**
# filtrar apenas os valores da coluna price menor do que 10
# criando uma tabela com nome de ''menor'' para receber essas informações

# %%
menor = arquivo[arquivo['price'] < 100]

# %%
display(menor)
# Out:
#                                                     name    host_id  \
# 3                        Cozy Entire Floor of Brownstone       4869
# 4       Entire Apt: Spacious Studio/Loft by central park       7192
# 6                                        BlissArtsSpace!       7356
# 7                       Large Furnished Room Near B'way        8967
# 8                     Cozy Clean Guest Room - Family Apt       7490
# 11                       Central Manhattan/near Broadway       7989
# 12        Lovely Room 1, Garden, Best Area, Legal rental       9744
# 13      Wonderful Guest Bedroom in Manhattan for SINGLES      11528
# 18       Hip Historic Brownstone Apartment with Backyard      20950
# 22                              CBG Helps Haiti Room#2.5      22486
# 25                    Sunny Bedroom Across Prospect Park      25326
# 26     Magnifique Suite au N de Manhattan - vue Cloitres      26394
# 28          SPACIOUS, LOVELY FURNISHED MANHATTAN BEDROOM      31374
# ...

# %% [markdown]
# comparando o arquivo completo chamado **arquivo** (que tem tudo) com o arquivo filtrado chamado **menor** (que tem apenas os price menor do que 100)

# %%
arquivo.shape
# Out:
# (48895, 13)

# %%
menor.shape
# Out:
# (21877, 13)

# %% [markdown]
# filtrando as **10 mais** revisadas do arquivo, utilizando isso na coluna number_of_reviews

# %%
maisrevisadas = menor.nlargest(10,'number_of_reviews' )

# %% [markdown]
# agora o arquivo chamado **arquivo** está completo e o arquivo chamado **maisrevisadas** está filtrado duas vezes (*price* menor do que 100 e *number_of_reviews* trazendo os 10 maiores )

# %% [markdown]
# Verificando quais os bairros existem listados nesse grupo (utilizando o arquivo **menor**)

# %%
maisrevisadas['neighbourhood_group'].unique()
# Out:
# array(['Queens', 'Manhattan', 'Brooklyn'], dtype=object)

# %% [markdown]
# Comparando com a listagem completa (nome do arquivo se chama **arquivo**)

# %%
arquivo['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
arquivo.shape
# Out:
# (48895, 13)

# %%
menor.shape
# Out:
# (21877, 13)

# %%
maisrevisadas.shape
# Out:
# (10, 13)

# %%
display(maisrevisadas)
# Out:
#                                                     name   host_id  \
# 11759                            Room near JFK Queen Bed  47621202
# 2031                          Great Bedroom in Manhattan   4734398
# 2030                      Beautiful Bedroom in Manhattan   4734398
# 2015                        Private Bedroom in Manhattan   4734398
# 13495                            Room Near JFK Twin Beds  47621202
# 10623                  Steps away from Laguardia airport  37312959
# 1879            Manhattan Lux Loft.Like.Love.Lots.Look !   2369681
# 20403  Cozy Room Family Home LGA Airport NO CLEANING FEE  26432133
# 471                      LG Private Room/Family Friendly    792159
# 1271                    My Little Guest Room in Flushing   2680820
#
#       neighbourhood_group    neighbourhood  latitude  longitude     room_type  \
# 11759              Queens          Jamaica  40.66730  -73.76831  Private room
# ...

# %% [markdown]
# agrupando por bairro

# %%
maisrevisadas['neighbourhood_group'].value_counts()
# Out:
# Queens       5
# Manhattan    4
# Brooklyn     1
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# 1 - **AB_NYC_2019** = arquivo original;
#
# 2 - **arquivo** = excluindo colunas *id | host_name | last_review*
#
# 3- **menor** = coluna *price* menor do que 100
#
# 4- **maisrevisadas** = os 10 maiores valores na coluna *number_of_reviews*

# %% [markdown]
# agrupando apenas para informações, quais *neighbourhood* aparecem mais vezes no arquivo **maisrevisadas** trazendo apenas o top 5

# %%
maisrevisadas['neighbourhood'].value_counts().head(5)
# Out:
# Harlem             3
# East Elmhurst      2
# Jamaica            2
# Flushing           1
# Lower East Side    1
# Name: neighbourhood, dtype: int64

# %%
maisrevisadas.shape
# Out:
# (10, 13)

# %%
menor['neighbourhood'].value_counts().head(5)
# Out:
# Bedford-Stuyvesant    2298
# Bushwick              1864
# Williamsburg          1759
# Harlem                1523
# Crown Heights          926
# Name: neighbourhood, dtype: int64

# %%
menor.shape
# Out:
# (21877, 13)

# %%
arquivo['neighbourhood'].value_counts().head(5)
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Name: neighbourhood, dtype: int64

# %%
arquivo.shape
# Out:
# (48895, 13)

# %% [markdown]
# 1 - **AB_NYC_2019** = arquivo original;
#
# 2 - **arquivo** = excluindo colunas *id | host_name | last_review*
#
# 3- **menor** = coluna *price* menor do que 100
#
# 4- **maisrevisadas** = os 10 maiores valores na coluna *number_of_reviews*

# %%
display(maisrevisadas)
# Out:
#                                                     name   host_id  \
# 11759                            Room near JFK Queen Bed  47621202
# 2031                          Great Bedroom in Manhattan   4734398
# 2030                      Beautiful Bedroom in Manhattan   4734398
# 2015                        Private Bedroom in Manhattan   4734398
# 13495                            Room Near JFK Twin Beds  47621202
# 10623                  Steps away from Laguardia airport  37312959
# 1879            Manhattan Lux Loft.Like.Love.Lots.Look !   2369681
# 20403  Cozy Room Family Home LGA Airport NO CLEANING FEE  26432133
# 471                      LG Private Room/Family Friendly    792159
# 1271                    My Little Guest Room in Flushing   2680820
#
#       neighbourhood_group    neighbourhood  latitude  longitude     room_type  \
# 11759              Queens          Jamaica  40.66730  -73.76831  Private room
# ...

# %%
sns.countplot(data=maisrevisadas, x='neighbourhood')

# %%
maisrevisadas['neighbourhood'].value_counts()
# Out:
# Harlem             3
# East Elmhurst      2
# Jamaica            2
# Flushing           1
# Lower East Side    1
# Bushwick           1
# Name: neighbourhood, dtype: int64

# %%
dezmaiscaro = arquivo.nlargest(10,'price')

# %% [markdown]
# 1 - **AB_NYC_2019** = arquivo original;
#
# 2 - **arquivo** = excluindo colunas *id | host_name | last_review*
#
# 3- **menor** = coluna *price* menor do que 100
#
# 4- **maisrevisadas** = os 10 maiores valores na coluna *number_of_reviews*
#
# 5 - **dezmaiscaro** = os 10 maiores valores da coluna *price* do arquivo original

# %%
display(dezmaiscaro)
# Out:
#                                                     name    host_id  \
# 9151                 Furnished room in Astoria apartment   20582832
# 17692    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 29238                                1-BR Lincoln Center   72390391
# 6530                                  Spanish Harlem Apt    1235070
# 12342                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 40433  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# 30268  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho   18128455
# 4377                                       Film Location    1177497
# 29662          East 72nd Townhouse by (Hidden by Airbnb)  156158778
# 42523                70' Luxury MotorYacht on the Hudson    7407743
#
#       neighbourhood_group      neighbourhood  latitude  longitude  \
# 9151               Queens            Astoria  40.76810  -73.91651
# 17692            Brooklyn         Greenpoint  40.73260  -73.95739
# ...

# %%
sns.countplot(data=dezmaiscaro, x='price')

# %%
dezmaiscaro.shape
# Out:
# (10, 13)

# %%
dezmaiscaro['price'].value_counts()
# Out:
# 9999     3
# 10000    3
# 7500     1
# 8000     1
# 7703     1
# 8500     1
# Name: price, dtype: int64

# %%
sns.countplot(data=maisrevisadas, x='neighbourhood')

# %% [markdown]
# **COMANDO PARA ORGANIZAR UM GRAFICO DO MAIOR PARA O MENOR**

# %% [markdown]
# 1 - **AB_NYC_2019** = arquivo original;
#
# 2 - **arquivo** = excluindo colunas *id | host_name | last_review*
#
# ### 3- **menor** = coluna *price* menor do que 100
#
# 4- **maisrevisadas** = os 10 maiores valores na coluna *number_of_reviews*
#
# 5 - **dezmaiscaro** = os 10 maiores valores da coluna *price* do arquivo original

# %% [markdown]
# #### UTILIZANDO O ARQUIVO menor (que contem os valores do arquivo original menor do que 100)

# %%
display(menor)
# Out:
#                                                     name    host_id  \
# 3                        Cozy Entire Floor of Brownstone       4869
# 4       Entire Apt: Spacious Studio/Loft by central park       7192
# 6                                        BlissArtsSpace!       7356
# 7                       Large Furnished Room Near B'way        8967
# 8                     Cozy Clean Guest Room - Family Apt       7490
# 11                       Central Manhattan/near Broadway       7989
# 12        Lovely Room 1, Garden, Best Area, Legal rental       9744
# 13      Wonderful Guest Bedroom in Manhattan for SINGLES      11528
# 18       Hip Historic Brownstone Apartment with Backyard      20950
# 22                              CBG Helps Haiti Room#2.5      22486
# 25                    Sunny Bedroom Across Prospect Park      25326
# 26     Magnifique Suite au N de Manhattan - vue Cloitres      26394
# 28          SPACIOUS, LOVELY FURNISHED MANHATTAN BEDROOM      31374
# ...

# %%
sns.countplot(data=menor, x='neighbourhood_group')

# %%
menor['neighbourhood_group'].value_counts()
# Out:
# Brooklyn         10904
# Manhattan         6036
# Queens            3865
# Bronx              823
# Staten Island      249
# Name: neighbourhood_group, dtype: int64

# %%
menorinorder = menor['neighbourhood_group'].value_counts().index

# %%
sns.countplot(data=menor, x='neighbourhood_group', order=menorinorder)

# %%
menor['neighbourhood_group'].value_counts()
# Out:
# Brooklyn         10904
# Manhattan         6036
# Queens            3865
# Bronx              823
# Staten Island      249
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# #### comparando o bairro com o tipo de quarto (utilizando o arquivo menor)

# %%
sns.countplot(data=menor, x='neighbourhood_group', hue='room_type')

# %%
menor['room_type'].value_counts()
# Out:
# Private room       17258
# Entire home/apt     3613
# Shared room         1006
# Name: room_type, dtype: int64

# %% [markdown]
# #### distribuição do preço do arquivo menor

# %%
sns.distplot(menor['price'])

# %%
menor['price'].value_counts().head(10)
# Out:
# 50    1534
# 60    1458
# 75    1370
# 80    1272
# 65    1190
# 70    1170
# 90    1021
# 55     950
# 45     891
# 85     877
# Name: price, dtype: int64

# %%
menor.shape
# Out:
# (21877, 13)

# %%
menor[menor['price']==60].shape
# Out:
# (1458, 13)

# %%
sns.distplot(arquivo['price'])

# %%
arquivo.shape
# Out:
# (48895, 13)

# %%
arquivo['price'].value_counts().head(15)
# Out:
# 100    2051
# 150    2047
# 50     1534
# 60     1458
# 200    1401
# 75     1370
# 80     1272
# 65     1190
# 70     1170
# 120    1130
# 125    1057
# 90     1021
# 250    1018
# 55      950
# 45      891
# Name: price, dtype: int64

# %%
arquivo[arquivo['price']<=271].shape
# Out:
# (44069, 13)

# %%
testedistribuicao = arquivo[arquivo['price'] <= 271]

# %%
sns.distplot(testedistribuicao['price'])

# %%
sns.countplot(data=menor, x='neighbourhood_group', hue='room_type')

# %%
ax = sns.countplot(y="neighbourhood_group", hue="room_type", data=menor)

# %%
ax = sns.countplot(y="neighbourhood_group", data=menor)

# %%
ax = sns.countplot(x="neighbourhood_group", data=menor, palette="Set1")

# %%
ax = sns.countplot(x="neighbourhood_group", data=menor,
                   facecolor=(1, 1, 1, 1),
                   linewidth=1,
                   edgecolor=sns.color_palette("dark", 5))

# %% [markdown]
# #### Distribuindo o preço de acordo com o bairro

# %%
sns.countplot(data=menor, x='neighbourhood_group', hue='room_type')

# %%
menor['room_type'].value_counts()
# Out:
# Private room       17258
# Entire home/apt     3613
# Shared room         1006
# Name: room_type, dtype: int64

# %%
plt.figure(figsize=(5, 3))
sns.violinplot(data=menor, x="neighbourhood_group", y="price")

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(data=arquivo, x="neighbourhood_group", y="price")

# %% [markdown]
# #### Utilizando Latitude (y) e Longitude (x)

# %%
menor.head()
# Out:
#                                                name  host_id  \
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
# 6                                   BlissArtsSpace!     7356
# 7                  Large Furnished Room Near B'way      8967
# 8                Cozy Clean Guest Room - Family Apt     7490
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 3            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4           Manhattan         East Harlem  40.79851  -73.94399
# 6            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8           Manhattan     Upper West Side  40.80178  -73.96723
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
# ...

# %%
menor.plot(
    kind='scatter',
    x='longitude',
    y='latitude',
    c='price',
    cmap='inferno',
    colorbar=True,
    alpha=0.8,
    figsize=(12,8))

# %%
i = urllib.request.urlopen('https://upload.wikimedia.org/wikipedia/commons/e/ec/Neighbourhoods_New_York_City_Map.PNG')
plt.imshow(plt.imread(i), zorder=0, extent=[-74.258, -73.7, 40.49, 40.92])
ax = plt.gca()
menor.plot(
    ax=ax,
    zorder=1,
    kind='scatter',
    x='longitude',
    y='latitude',
    c='price',
    cmap='inferno',
    colorbar=True,
    alpha=0.8,
    figsize=(12,8))

# %%
menor['latitude'].value_counts()

# %%
menor['longitude'].value_counts()
