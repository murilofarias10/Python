# %%
# ============================================
# Decision Tree Classifier on iris.csv
# (Fixed columns: 4 features + target 'Species')
# ============================================

# Step 1: Import required libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_graphviz, export_text
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import graphviz
#from google.colab import files

# Step 2: Upload iris.csv file
#print("Please upload your iris.csv file")
#uploaded = files.upload()

# Step 3: Read uploaded file
#file_name = list(uploaded.keys())[0]
data = pd.read_csv('iris.csv')
#data = pd.read_csv(file_name)
print("\nFirst 5 rows:\n", data.head())

# Step 4: Define predictors and target
predictors = ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width']
target_col = 'Species'


# Step 5: Separate features (X) and target (y)
X = data[predictors]
y = data[target_col]

# Step 6: Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Step 7: Train Decision Tree with depth=10 and leaf size=5
model = DecisionTreeClassifier(
    random_state=42,
    max_depth=10,
    min_samples_leaf=5
)
model.fit(X_train, y_train)

# Step 8: Make predictions
y_pred = model.predict(X_test)

# Step 9: Evaluate performance
print("\n Model Accuracy:", accuracy_score(y_test, y_pred))

# Step 10: Visualize Decision Tree
plt.figure(figsize=(16,10))
plot_tree(
    model,
    filled=True,
    feature_names=predictors,
    class_names=[str(c) for c in model.classes_],
    rounded=True,
    fontsize=10
)
plt.title("Decision Tree of Iris Dataset", fontsize=16)
plt.show()

# Step 11: Save tree as PNG
dot_data = export_graphviz(
    model,
    out_file=None,
    feature_names=predictors,
    class_names=[str(c) for c in model.classes_],
    filled=True,
    rounded=True,
    special_characters=True
)
graph = graphviz.Source(dot_data)
graph.render("iris_decision_tree_depth_leaf", format="png", cleanup=True)

print("\n🌳 The decision tree has been saved as 'iris_decision_tree_depth_leaf.png'.")

# Step 12: Download PNG
files.download("iris_decision_tree_depth_leaf.png")

# ============================================
# Step 13: Print Decision Rules from the Tree
# ============================================
rules = export_text(model, feature_names=predictors)
print("\n Decision Tree Rules:\n")
print(rules)
# Out:
# Please upload your iris.csv file
#      <input type="file" id="files-825d6af6-e38d-4096-83ae-2cab7fec20c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-825d6af6-e38d-4096-83ae-2cab7fec20c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
#Murilo From here

# %%
# ============================================
# Decision Tree Classifier on iris.csv
# (Fixed columns: 4 features + target 'Species')
# ============================================

# %%
# !pip install graphviz

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_graphviz, export_text
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import graphviz

# %%
#file_name = list(uploaded.keys())[0]
data = pd.read_csv('iris.csv')
#data = pd.read_csv(file_name)
print("\nFirst 5 rows:\n", data.head())
# Out:
# First 5 rows:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Step 4: Define predictors and target
predictors = ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width']
target_col = 'Species'

# %%
# Step 5: Separate features (X) and target (y)
X = data[predictors]
y = data[target_col]

# Step 6: Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Step 7: Train Decision Tree with depth=10 and leaf size=5
model = DecisionTreeClassifier(
    random_state=42,
    max_depth=10,
    min_samples_leaf=5
)
model.fit(X_train, y_train)

# Step 8: Make predictions
y_pred = model.predict(X_test)

# %%
# Step 9: Evaluate performance
print("\n Model Accuracy:", accuracy_score(y_test, y_pred))
# Out:
#  Model Accuracy: 1.0

# %%
# Step 10: Visualize Decision Tree
plt.figure(figsize=(16,10))
plot_tree(
    model,
    filled=True,
    feature_names=predictors,
    class_names=[str(c) for c in model.classes_],
    rounded=True,
    fontsize=10
)
plt.title("Decision Tree of Iris Dataset", fontsize=16)
plt.show()

# %%
# Step 11: Save tree as PNG
dot_data = export_graphviz(
    model,
    out_file=None,
    feature_names=predictors,
    class_names=[str(c) for c in model.classes_],
    filled=True,
    rounded=True,
    special_characters=True
)
graph = graphviz.Source(dot_data)
graph.render("iris_decision_tree_depth_leaf", format="png", cleanup=True)

print("\n🌳 The decision tree has been saved as 'iris_decision_tree_depth_leaf.png'.")

# Step 12: Download PNG
files.download("iris_decision_tree_depth_leaf.png")

# ============================================
# Step 13: Print Decision Rules from the Tree
# ============================================
rules = export_text(model, feature_names=predictors)
print("\n Decision Tree Rules:\n")
print(rules)

# %%
######################### First approach

# %%
#Murilo Farias
# Step 1: Import required libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_graphviz, export_text
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import graphviz

# %%
data = pd.read_csv('Social_Network_Ads.csv')

# %%
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
# Step 4: Define predictors and target
predictors = ['Age', 'EstimatedSalary']
target_col = 'Purchased'

# %%
# Step 5: Separate features (X) and target (y)
X = data[predictors]
y = data[target_col]

# %%
# Step 6: Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# Step 7: Train Decision Tree with depth=10 and leaf size=5
model = DecisionTreeClassifier(
    random_state=42,
    max_depth=10,
    min_samples_leaf=5
)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=5, random_state=42)

# %%
# Step 8: Make predictions
y_pred = model.predict(X_test)

# %%
# Step 9: Evaluate performance
print("\n Model Accuracy:", accuracy_score(y_test, y_pred))

# Step 10: Visualize Decision Tree
plt.figure(figsize=(16,10))
plot_tree(
    model,
    filled=True,
    feature_names=predictors,
    class_names=[str(c) for c in model.classes_],
    rounded=True,
    fontsize=10
)
# Out:
#  Model Accuracy: 0.9333333333333333
# [Text(0.4868421052631579, 0.9375, 'Age <= 42.5\ngini = 0.451\nsamples = 280\nvalue = [184, 96]\nclass = 0'),
#  Text(0.2631578947368421, 0.8125, 'EstimatedSalary <= 90500.0\ngini = 0.284\nsamples = 204\nvalue = [169, 35]\nclass = 0'),
#  Text(0.375, 0.875, 'True  '),
#  Text(0.10526315789473684, 0.6875, 'Age <= 36.5\ngini = 0.078\nsamples = 172\nvalue = [165.0, 7.0]\nclass = 0'),
#  Text(0.05263157894736842, 0.5625, 'gini = 0.0\nsamples = 115\nvalue = [115, 0]\nclass = 0'),
#  Text(0.15789473684210525, 0.5625, 'EstimatedSalary <= 67500.0\ngini = 0.215\nsamples = 57\nvalue = [50, 7]\nclass = 0'),
#  Text(0.10526315789473684, 0.4375, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]\nclass = 0'),
#  Text(0.21052631578947367, 0.4375, 'EstimatedSalary <= 78500.0\ngini = 0.358\nsamples = 30\nvalue = [23, 7]\nclass = 0'),
#  Text(0.15789473684210525, 0.3125, 'EstimatedSalary <= 71500.0\ngini = 0.287\nsamples = 23\nvalue = [19, 4]\nclass = 0'),
# ...

# %%
#second apprach using hot encoder

# %%
# Step 1: Import required libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Step 2: Load the dataset
data = pd.read_csv('Social_Network_Ads.csv')
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
data = pd.get_dummies(data, columns=['Gender'], drop_first=False)

# %%
data.head()
# Out:
#     User ID  Age  EstimatedSalary  Purchased  Gender_Female  Gender_Male
# 0  15624510   19            19000          0          False         True
# 1  15810944   35            20000          0          False         True
# 2  15668575   26            43000          0           True        False
# 3  15603246   27            57000          0           True        False
# 4  15804002   19            76000          0          False         True

# %%
predictors = ['Age', 'EstimatedSalary', 'Gender_Female', 'Gender_Male']
target_col = 'Purchased'

# %%
X = data[predictors]
y = data[target_col]

# %%
# Step 6: Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# Step 7: Train Decision Tree
model = DecisionTreeClassifier(
    random_state=42,
    max_depth=10,
    min_samples_leaf=5
)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=5, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
# Step 9: Evaluate performance
print("\nModel Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Model Accuracy: 0.9333333333333333

# %%
# Step 10: Visualize Decision Tree
plt.figure(figsize=(30,25))
plot_tree(
    model,
    filled=True,
    feature_names=predictors,
    class_names=[str(c) for c in model.classes_],
    rounded=True,
    fontsize=10
)
plt.show()
