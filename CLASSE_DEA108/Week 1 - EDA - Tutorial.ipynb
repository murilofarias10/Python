# %% [markdown]
# ## Import Required Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Import Data

# %%
df=pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# No Null Value - Clean Dataset !

# %%
# Check for Duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %% [markdown]
# No Duplicates

# %%
# Plot
plt.title('Count of Number of Each Outcome')
sns.countplot(x='Outcome',data=df)
# Out:
# <Axes: title={'center': 'Count of Number of Each Outcome'}, xlabel='Outcome', ylabel='count'>

# %% [markdown]
# Slightly Unbalance Dataset here 35:65 1:0 ratio

# %%
# Print Pearson R correlation matrix
corr_matrix = df.corr(method='pearson')
corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
# Sort the correlations from highest to lowest, for 'Outcome' only.
corr_matrix[['Outcome']].unstack().sort_values(ascending=False)
# Out:
# Outcome  Outcome                     1.000000
#          Glucose                     0.466581
#          BMI                         0.292695
#          Age                         0.238356
#          Pregnancies                 0.221898
#          DiabetesPedigreeFunction    0.173844
#          Insulin                     0.130548
#          SkinThickness               0.074752
#          BloodPressure               0.065068
# dtype: float64

# %%
# Visualize correlation matrix, which will show the correlations between the predictor variables with each other, and with the target ('Outcome')
corr_matrix.style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_ccaa8_row0_col0, #T_ccaa8_row1_col1, #T_ccaa8_row2_col2, #T_ccaa8_row3_col3, #T_ccaa8_row4_col4, #T_ccaa8_row5_col5, #T_ccaa8_row6_col6, #T_ccaa8_row7_col7, #T_ccaa8_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ccaa8_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_ccaa8_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_ccaa8_row0_col3, #T_ccaa8_row7_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_ccaa8_row0_col4, #T_ccaa8_row0_col5, #T_ccaa8_row0_col6, #T_ccaa8_row2_col8, #T_ccaa8_row3_col0, #T_ccaa8_row3_col1, #T_ccaa8_row3_col7, #T_ccaa8_row6_col2, #T_ccaa8_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ccaa8_row0_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_ccaa8_row0_col8, #T_ccaa8_row1_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ccaa8_row1_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ccaa8_row1_col2, #T_ccaa8_row6_col8 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ccaa8_row1_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_ccaa8_row1_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_ccaa8_row1_col5, #T_ccaa8_row3_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_ccaa8_row1_col7 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_ccaa8_row1_col8 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_ccaa8_row2_col0, #T_ccaa8_row7_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_ccaa8_row2_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_ccaa8_row2_col3 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_ccaa8_row2_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_ccaa8_row2_col5, #T_ccaa8_row6_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_ccaa8_row2_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_ccaa8_row2_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_ccaa8_row3_col2, #T_ccaa8_row5_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ccaa8_row3_col4 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_ccaa8_row3_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_ccaa8_row3_col8 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_ccaa8_row4_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_ccaa8_row4_col1 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_ccaa8_row4_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ccaa8_row4_col3 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_ccaa8_row4_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_ccaa8_row4_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_ccaa8_row4_col7, #T_ccaa8_row7_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ccaa8_row4_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_ccaa8_row5_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_ccaa8_row5_col2, #T_ccaa8_row5_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ccaa8_row5_col3 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_ccaa8_row5_col6, #T_ccaa8_row8_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_ccaa8_row5_col7 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ccaa8_row5_col8 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_ccaa8_row6_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_ccaa8_row6_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_ccaa8_row6_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_ccaa8_row6_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_ccaa8_row6_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_ccaa8_row7_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_ccaa8_row7_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ccaa8_row7_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_ccaa8_row7_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_ccaa8_row8_col0, #T_ccaa8_row8_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_ccaa8_row8_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_ccaa8_row8_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ccaa8_row8_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_ccaa8_row8_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_ccaa8_row8_col7 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# </style>
# <table id="T_ccaa8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccaa8_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_ccaa8_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_ccaa8_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_ccaa8_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_ccaa8_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_ccaa8_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_ccaa8_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_ccaa8_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_ccaa8_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccaa8_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_ccaa8_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_ccaa8_row0_col1" class="data row0 col1" >0.13</td>
#       <td id="T_ccaa8_row0_col2" class="data row0 col2" >0.14</td>
#       <td id="T_ccaa8_row0_col3" class="data row0 col3" >-0.08</td>
#       <td id="T_ccaa8_row0_col4" class="data row0 col4" >-0.07</td>
#       <td id="T_ccaa8_row0_col5" class="data row0 col5" >0.02</td>
#       <td id="T_ccaa8_row0_col6" class="data row0 col6" >-0.03</td>
#       <td id="T_ccaa8_row0_col7" class="data row0 col7" >0.54</td>
#       <td id="T_ccaa8_row0_col8" class="data row0 col8" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_ccaa8_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_ccaa8_row1_col0" class="data row1 col0" >0.13</td>
#       <td id="T_ccaa8_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_ccaa8_row1_col2" class="data row1 col2" >0.15</td>
#       <td id="T_ccaa8_row1_col3" class="data row1 col3" >0.06</td>
#       <td id="T_ccaa8_row1_col4" class="data row1 col4" >0.33</td>
#       <td id="T_ccaa8_row1_col5" class="data row1 col5" >0.22</td>
#       <td id="T_ccaa8_row1_col6" class="data row1 col6" >0.14</td>
#       <td id="T_ccaa8_row1_col7" class="data row1 col7" >0.26</td>
#       <td id="T_ccaa8_row1_col8" class="data row1 col8" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_ccaa8_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_ccaa8_row2_col0" class="data row2 col0" >0.14</td>
#       <td id="T_ccaa8_row2_col1" class="data row2 col1" >0.15</td>
#       <td id="T_ccaa8_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_ccaa8_row2_col3" class="data row2 col3" >0.21</td>
#       <td id="T_ccaa8_row2_col4" class="data row2 col4" >0.09</td>
#       <td id="T_ccaa8_row2_col5" class="data row2 col5" >0.28</td>
#       <td id="T_ccaa8_row2_col6" class="data row2 col6" >0.04</td>
#       <td id="T_ccaa8_row2_col7" class="data row2 col7" >0.24</td>
#       <td id="T_ccaa8_row2_col8" class="data row2 col8" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_ccaa8_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_ccaa8_row3_col0" class="data row3 col0" >-0.08</td>
#       <td id="T_ccaa8_row3_col1" class="data row3 col1" >0.06</td>
#       <td id="T_ccaa8_row3_col2" class="data row3 col2" >0.21</td>
#       <td id="T_ccaa8_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_ccaa8_row3_col4" class="data row3 col4" >0.44</td>
#       <td id="T_ccaa8_row3_col5" class="data row3 col5" >0.39</td>
#       <td id="T_ccaa8_row3_col6" class="data row3 col6" >0.18</td>
#       <td id="T_ccaa8_row3_col7" class="data row3 col7" >-0.11</td>
#       <td id="T_ccaa8_

# %% [markdown]
# ## Distributions

# %%
df.hist(bins=20,figsize=(10, 10))
plt.show()

# %%
sns.heatmap(df.corr(), annot = True)
plt.show()
