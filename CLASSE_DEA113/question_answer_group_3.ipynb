# %% [markdown]
# Question 3: information_extraction.ipynb — Named Entity Recognition

# %% [markdown]
# 1 - Add 2 new texts containing PERSON, ORG, and DATE or GPE entities
# 2 - Extract entities using spaCy

# %%
# !pip -q install spacy

# %%
# !python -m spacy download en_core_web_sm -q
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
import pandas as pd

# %%
nlp = spacy.load("en_core_web_sm")

# %%
texts = [
    "Dr. Angela Susan Mathew joined Simon Fraser University in 2021.",
    "Ronald started working at Google Canada in Vancouver.",
    "Murilo Farias is studying Data Engineering at Canadian College of Technology and Business.",
    "Jeff and Ronald attended a workshop hosted by Microsoft.",
    "Amazon opened a new office in Vancouver in 2022.",
    "Sarah Thompson was hired by IBM last year.",
    "The project was developed by engineers from Meta.",
    "Murilo and Jeff collaborated on a project at CCTB.",
    "Apple announced a partnership with Simon Fraser University.",
    "Dr. John Smith works as a researcher at Google.",
    "Microsoft Canada organized an AI conference in Toronto.",
    "Angela Mathew presented her research at UBC.",
    "Ronald moved to Vancouver to work for Amazon.",
    "IBM hired new data engineers from CCTB.",
    "Jeff joined a startup backed by Google Ventures.",
    "Murilo completed an internship at Microsoft.",
    "The team from Meta visited Simon Fraser University.",
    "Sarah and John are employees of Apple.",
    "Amazon Web Services hired engineers in Canada.",
    "Google collaborated with IBM on a cloud project."
]

# %%
rows = []

# %%
for doc_id, text in enumerate(texts, start=1):

    # Process the text through spaCy pipeline
    doc = nlp(text)

    # Each ent is an entity object with .text and .label_
    for ent in doc.ents:

        rows.append({
            "doc_id": doc_id,         # which document this entity came from
            "text": text,             # original text
            "entity_text": ent.text,  # the exact string spaCy marked as an entity
            "entity_label": ent.label_ # entity type (PERSON, ORG, GPE, DATE, etc.)
        })

# %%
entities_df = pd.DataFrame(rows)

# %%
entities_df
# Out:
#     doc_id                                               text  \
# 0        1  Dr. Angela Susan Mathew joined Simon Fraser Un...
# 1        1  Dr. Angela Susan Mathew joined Simon Fraser Un...
# 2        1  Dr. Angela Susan Mathew joined Simon Fraser Un...
# 3        2  Ronald started working at Google Canada in Van...
# 4        2  Ronald started working at Google Canada in Van...
# 5        2  Ronald started working at Google Canada in Van...
# 6        3  Murilo Farias is studying Data Engineering at ...
# 7        3  Murilo Farias is studying Data Engineering at ...
# 8        3  Murilo Farias is studying Data Engineering at ...
# 9        4  Jeff and Ronald attended a workshop hosted by ...
# 10       4  Jeff and Ronald attended a workshop hosted by ...
# 11       4  Jeff and Ronald attended a workshop hosted by ...
# 12       5   Amazon opened a new office in Vancouver in 2022.
# 13       5   Amazon opened a new office in Vancouver in 2022.
# 14       5   Amazon opened a new office in Vancouver in 2022.
# 15       6         Sarah Thompson was hired by IBM last year.
# 16       6         Sarah Thompson was hired by IBM last year.
# 17       6         Sarah Thompson was hired by IBM last year.
# 18       7  The project was developed by engineers from Meta.
# 19       8  Murilo and Jeff collaborated on a project at C...
# 20       9  Apple announced a partnership with Simon Frase...
# 21       9  Apple announced a partnership with Simon Frase...
# 22      10    Dr. John Smith works as a researcher at Google.
# 23      10    Dr. John Smith works as a researcher at Google.
# 24      11  Microsoft Canada organized an AI conference in...
# 25      11  Microsoft Canada organized an AI conference in...
# 26      11  Microsoft Canada organized an AI conference in...
# 27      12       Angela Mathew presented her research at UBC.
# 28      13      Ronald moved to Vancouver to work for Amazon.
# 29      13      Ronald moved to Vancouver to work for Amazon.
# 30      13      Ronald moved to Vancouver to work for Amazon.
# 31      14            IBM hired new data engineers from CCTB.
# 32      15   Jeff joined a startup backed by Google Ventures.
# 33      15   Jeff joined a startup backed by Google Ventures.
# 34      16       Murilo completed an internship at Microsoft.
# 35      17  The team from Meta visited Simon Fraser Univer...
# 36      17  The team from Meta visited Simon Fraser Univer...
# 37      18             Sarah and John are employees of Apple.
# 38      18             Sarah and John are employees of Apple.
# 39      18             Sarah and John are employees of Apple.
# 40      19     Amazon Web Services hired engineers in Canada.
# 41      19     Amazon Web Services hired engineers in Canada.
# 42      20   Google collaborated with IBM on a cloud project.
# 43      20   Google collaborated with IBM on a cloud project.
#
#                                     entity_text entity_label
# 0                           Angela Susan Mathew       PERSON
# 1                       Simon Fraser University          ORG
# 2                                          2021         DATE
# 3                                        Ronald       PERSON
# 4                                 Google Canada          ORG
# 5                                     Vancouver          GPE
# 6                                 Murilo Farias       PERSON
# 7                              Data Engineering          ORG
# 8   Canadian College of Technology and Business          ORG
# 9                                          Jeff       PERSON
# 10                                       Ronald       PERSON
# 11                                    Microsoft          ORG
# 12                                       Amazon          ORG
# 13                                    Vancouver          GPE
# 14                                         2022         DATE
# 15                               Sarah Thompson       PERSON
# 16                                          IBM          ORG
# 17                                    last year         DATE
# 18                                         Meta          ORG
# 19                                         Jeff       PERSON
# 20                                        Apple          ORG
# 21                      Simon Fraser University          ORG
# 22                                   John Smith       PERSON
# 23                                       Google          ORG
# 24                             Microsoft Canada          ORG
# 25                                           AI          GPE
# 26                                      Toronto          GPE
# 27                                Angela Mathew       PERSON
# 28                                       Ronald       PERSON
# 29                                    Vancouver          GPE
# 30                                       Amazon          ORG
# 31                                          IBM          ORG
# 32                                         Jeff       PERSON
# 33                              Google Ventures          ORG
# 34                                    Microsoft          ORG
# 35                                         Meta          ORG
# 36                                 Simon Fraser       PERSON
# 37                                        Sarah       PERSON
# 38                                         John       PERSON
# 39                                        Apple          ORG
# 40                          Amazon Web Services          ORG
# 41                                       Canada          GPE
# 42                                       Google          ORG
# 43                                          IBM          ORG

# %% [markdown]
# 3 - Filter results to include only PERSON and ORG

# %%
entities_df_filters = entities_df[entities_df["entity_label"].isin(["PERSON", "ORG"])]

# %%
entities_df_filters
# Out:
#     doc_id                                               text  \
# 0        1  Dr. Angela Susan Mathew joined Simon Fraser Un...
# 1        1  Dr. Angela Susan Mathew joined Simon Fraser Un...
# 3        2  Ronald started working at Google Canada in Van...
# 4        2  Ronald started working at Google Canada in Van...
# 6        3  Murilo Farias is studying Data Engineering at ...
# 7        3  Murilo Farias is studying Data Engineering at ...
# 8        3  Murilo Farias is studying Data Engineering at ...
# 9        4  Jeff and Ronald attended a workshop hosted by ...
# 10       4  Jeff and Ronald attended a workshop hosted by ...
# 11       4  Jeff and Ronald attended a workshop hosted by ...
# 12       5   Amazon opened a new office in Vancouver in 2022.
# 15       6         Sarah Thompson was hired by IBM last year.
# 16       6         Sarah Thompson was hired by IBM last year.
# 18       7  The project was developed by engineers from Meta.
# 19       8  Murilo and Jeff collaborated on a project at C...
# 20       9  Apple announced a partnership with Simon Frase...
# 21       9  Apple announced a partnership with Simon Frase...
# 22      10    Dr. John Smith works as a researcher at Google.
# 23      10    Dr. John Smith works as a researcher at Google.
# 24      11  Microsoft Canada organized an AI conference in...
# 27      12       Angela Mathew presented her research at UBC.
# 28      13      Ronald moved to Vancouver to work for Amazon.
# 30      13      Ronald moved to Vancouver to work for Amazon.
# 31      14            IBM hired new data engineers from CCTB.
# 32      15   Jeff joined a startup backed by Google Ventures.
# 33      15   Jeff joined a startup backed by Google Ventures.
# 34      16       Murilo completed an internship at Microsoft.
# 35      17  The team from Meta visited Simon Fraser Univer...
# 36      17  The team from Meta visited Simon Fraser Univer...
# 37      18             Sarah and John are employees of Apple.
# 38      18             Sarah and John are employees of Apple.
# 39      18             Sarah and John are employees of Apple.
# 40      19     Amazon Web Services hired engineers in Canada.
# 42      20   Google collaborated with IBM on a cloud project.
# 43      20   Google collaborated with IBM on a cloud project.
#
#                                     entity_text entity_label
# 0                           Angela Susan Mathew       PERSON
# 1                       Simon Fraser University          ORG
# 3                                        Ronald       PERSON
# 4                                 Google Canada          ORG
# 6                                 Murilo Farias       PERSON
# 7                              Data Engineering          ORG
# 8   Canadian College of Technology and Business          ORG
# 9                                          Jeff       PERSON
# 10                                       Ronald       PERSON
# 11                                    Microsoft          ORG
# 12                                       Amazon          ORG
# 15                               Sarah Thompson       PERSON
# 16                                          IBM          ORG
# 18                                         Meta          ORG
# 19                                         Jeff       PERSON
# 20                                        Apple          ORG
# 21                      Simon Fraser University          ORG
# 22                                   John Smith       PERSON
# 23                                       Google          ORG
# 24                             Microsoft Canada          ORG
# 27                                Angela Mathew       PERSON
# 28                                       Ronald       PERSON
# 30                                       Amazon          ORG
# 31                                          IBM          ORG
# 32                                         Jeff       PERSON
# 33                              Google Ventures          ORG
# 34                                    Microsoft          ORG
# 35                                         Meta          ORG
# 36                                 Simon Fraser       PERSON
# 37                                        Sarah       PERSON
# 38                                         John       PERSON
# 39                                        Apple          ORG
# 40                          Amazon Web Services          ORG
# 42                                       Google          ORG
# 43                                          IBM          ORG

# %% [markdown]
# 4 - Create a frequency table of extracted entities

# %%
freq_table = (
    entities_df_filters
    #.groupby(["entity_text", "entity_label"])
    .groupby(["entity_text"])
    .size()
    .reset_index(name="frequency")
    .sort_values("frequency", ascending=False)
)

freq_table

#we are using the entity_text to count the frequency of each entity
# Out:
#                                     entity_text  frequency
# 11                                         Jeff          3
# 18                                       Ronald          3
# 10                                          IBM          3
# 7                                        Google          2
# 15                                    Microsoft          2
# 14                                         Meta          2
# 0                                        Amazon          2
# 4                                         Apple          2
# 22                      Simon Fraser University          2
# 6                              Data Engineering          1
# 8                                 Google Canada          1
# 9                               Google Ventures          1
# 5   Canadian College of Technology and Business          1
# 1                           Amazon Web Services          1
# 12                                         John          1
# 13                                   John Smith          1
# 3                           Angela Susan Mathew          1
# 16                             Microsoft Canada          1
# 17                                Murilo Farias          1
# 2                                 Angela Mathew          1
# 19                                        Sarah          1
# 20                               Sarah Thompson          1
# 21                                 Simon Fraser          1

# %% [markdown]
# 5 - Display the top 10 most frequent entities

# %%
top_10_entities = (
    freq_table
    .sort_values(by="frequency", ascending=False)
    .head(10)
)

# %%
top_10_entities
# Out:
#                 entity_text  frequency
# 11                     Jeff          3
# 10                      IBM          3
# 18                   Ronald          3
# 7                    Google          2
# 15                Microsoft          2
# 14                     Meta          2
# 0                    Amazon          2
# 4                     Apple          2
# 22  Simon Fraser University          2
# 3       Angela Susan Mathew          1
