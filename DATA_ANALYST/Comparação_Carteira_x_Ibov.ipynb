# %% [markdown]
# <a href="https://colab.research.google.com/github/murilofarias10/AnaliseComPython/blob/main/Compara%C3%A7%C3%A3o_Carteira_x_Ibov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Instalando e importando bibliotecas

# %%
# !pip install yfinance #instalando API yahoo finance

# %%
import yfinance as yf #yahoo finance
import pandas as pd #pandas

# %% [markdown]
# ## 2. Meus Ativos

# %%
ativos = ['VIIA3.SA','OIBR3.SA','SAPR4.SA','IRBR3.SA','EVEN3.SA'] #Nomes do meus ativos.SA (o .SA é para consultar API no yahoo)

# %%
inicio = '2020-12-07' #ano mes dia
fim = '2021-10-07' #ano mes dia

# %%
precos = pd.DataFrame() #criando dataframe vazio

for i in ativos: #para cada ativo na lista de ativos
  precos[i] = yf.download(i, start = inicio, end = fim)['Adj Close'] #valida para o ativo trazendo 'ADJ CLOSE'
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
precos.iloc[::-1] #Invertendo a lista para visualização
# Out:
#              VIIA3.SA  OIBR3.SA  SAPR4.SA  IRBR3.SA   EVEN3.SA
# Date
# 2021-10-06   8.120000      0.94  3.760000      4.84   7.420000
# 2021-10-05   7.850000      0.98  3.760000      4.83   7.530000
# 2021-10-04   7.700000      0.98  3.770000      4.85   7.770000
# 2021-10-01   8.290000      1.00  3.830000      4.94   8.120000
# 2021-09-30   7.710000      1.00  3.850000      4.73   7.690000
# ...               ...       ...       ...       ...        ...
# 2020-12-11  16.820000      2.36  4.925322      7.28  11.671668
# 2020-12-10  17.020000      2.43  4.896631      7.38  11.671668
# 2020-12-09  17.209999      2.45  4.887067      7.26  11.755369
# 2020-12-08  17.700001      2.33  4.925322      7.53  11.811170
# 2020-12-07  17.430000      2.26  4.954013      7.36  11.866971
#
# [205 rows x 5 columns]

# %%
precos
# Out:
#              VIIA3.SA  OIBR3.SA  SAPR4.SA  IRBR3.SA   EVEN3.SA
# Date
# 2020-12-07  17.430000      2.26  4.954013      7.36  11.866971
# 2020-12-08  17.700001      2.33  4.925322      7.53  11.811170
# 2020-12-09  17.209999      2.45  4.887067      7.26  11.755369
# 2020-12-10  17.020000      2.43  4.896631      7.38  11.671668
# 2020-12-11  16.820000      2.36  4.925322      7.28  11.671668
# ...               ...       ...       ...       ...        ...
# 2021-09-30   7.710000      1.00  3.850000      4.73   7.690000
# 2021-10-01   8.290000      1.00  3.830000      4.94   8.120000
# 2021-10-04   7.700000      0.98  3.770000      4.85   7.770000
# 2021-10-05   7.850000      0.98  3.760000      4.83   7.530000
# 2021-10-06   8.120000      0.94  3.760000      4.84   7.420000
#
# [205 rows x 5 columns]

# %%
precos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 205 entries, 2020-12-07 to 2021-10-06
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   VIIA3.SA  205 non-null    float64
#  1   OIBR3.SA  205 non-null    float64
#  2   SAPR4.SA  205 non-null    float64
#  3   IRBR3.SA  205 non-null    float64
#  4   EVEN3.SA  205 non-null    float64
# dtypes: float64(5)
# memory usage: 9.6 KB

# %%
#Se necessario utilizar, precos = precos.fillna(1) #Alterando valor Nan do dataframe para 1

# %%
precos
# Out:
#              VIIA3.SA  OIBR3.SA  SAPR4.SA  IRBR3.SA   EVEN3.SA
# Date
# 2020-12-07  17.430000      2.26  4.954013      7.36  11.866971
# 2020-12-08  17.700001      2.33  4.925322      7.53  11.811170
# 2020-12-09  17.209999      2.45  4.887067      7.26  11.755369
# 2020-12-10  17.020000      2.43  4.896631      7.38  11.671668
# 2020-12-11  16.820000      2.36  4.925322      7.28  11.671668
# ...               ...       ...       ...       ...        ...
# 2021-09-30   7.710000      1.00  3.850000      4.73   7.690000
# 2021-10-01   8.290000      1.00  3.830000      4.94   8.120000
# 2021-10-04   7.700000      0.98  3.770000      4.85   7.770000
# 2021-10-05   7.850000      0.98  3.760000      4.83   7.530000
# 2021-10-06   8.120000      0.94  3.760000      4.84   7.420000
#
# [205 rows x 5 columns]

# %%
precos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 205 entries, 2020-12-07 to 2021-10-06
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   VIIA3.SA  205 non-null    float64
#  1   OIBR3.SA  205 non-null    float64
#  2   SAPR4.SA  205 non-null    float64
#  3   NGRD3.SA  205 non-null    float64
#  4   IRBR3.SA  205 non-null    float64
#  5   MOSI3.SA  205 non-null    float64
#  6   EVEN3.SA  205 non-null    float64
# dtypes: float64(7)
# memory usage: 12.8 KB

# %%
normalizado = precos/precos.iloc[0] #dividino cada item pelo valor do primeiro item

# %%
normalizado
# Out:
#             VIIA3.SA  OIBR3.SA  SAPR4.SA  IRBR3.SA  EVEN3.SA
# Date
# 2020-12-07  1.000000  1.000000  1.000000  1.000000  1.000000
# 2020-12-08  1.015491  1.030973  0.994208  1.023098  0.995298
# 2020-12-09  0.987378  1.084071  0.986487  0.986413  0.990596
# 2020-12-10  0.976477  1.075221  0.988417  1.002717  0.983542
# 2020-12-11  0.965003  1.044248  0.994208  0.989130  0.983542
# ...              ...       ...       ...       ...       ...
# 2021-09-30  0.442341  0.442478  0.777148  0.642663  0.648017
# 2021-10-01  0.475617  0.442478  0.773111  0.671196  0.684252
# 2021-10-04  0.441767  0.433628  0.760999  0.658967  0.654758
# 2021-10-05  0.450373  0.433628  0.758981  0.656250  0.634534
# 2021-10-06  0.465863  0.415929  0.758981  0.657609  0.625265
#
# [205 rows x 5 columns]

# %%
#Minha carteira:

import matplotlib.pyplot as plt

plt.style.use('dark_background')
normalizado.plot(figsize = (8,8));
plt.title('Carteira - Murilo Farias')
# Out:
# Text(0.5, 1.0, 'Carteira - Murilo Farias')

# %% [markdown]
# ## 3. Obtendo dados do IBOV

# %%
ibov = yf.download('^BVSP', start = inicio, end = fim) #trazendo valores do ibov
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov.head() #apresentando dados ibov
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2020-12-07  113751.0  114531.0  112629.0  113625.0   113625.0   9633900
# 2020-12-08  113590.0  114381.0  112820.0  113571.0   113571.0   8810900
# 2020-12-09  113799.0  114020.0  112567.0  112722.0   112722.0   8431100
# 2020-12-10  113002.0  115262.0  112732.0  114992.0   114992.0  11803600
# 2020-12-11  115128.0  115527.0  113949.0  115323.0   115323.0   8372300

# %%
ibov.rename(columns = {'Adj Close': 'IBOV'}, inplace = True) #alterando nome da coluna para ibov

# %%
ibov = ibov.drop(ibov.columns[[0,1,2,3,5]], axis = 1) #excluindo outras colunas e mantendo apenas coluna IBOV

# %%
ibov
# Out:
#                 IBOV
# Date
# 2020-12-07  113625.0
# 2020-12-08  113571.0
# 2020-12-09  112722.0
# 2020-12-10  114992.0
# 2020-12-11  115323.0
# ...              ...
# 2021-09-30  110979.0
# 2021-10-01  112900.0
# 2021-10-04  110393.0
# 2021-10-05  110458.0
# 2021-10-06  110560.0
#
# [205 rows x 1 columns]

# %%
import matplotlib.pyplot as plt


plt.style.use('dark_background')
plt.title('IBOV')
ibov['IBOV'].plot(figsize = (10,10));
plt.legend()

# %%
ibov.index = pd.to_datetime(ibov.index) #Verificando se o índice dos dataframes está no formato 'data'

# %%
precos.index = pd.to_datetime(precos.index) #Verificando se o índice dos dataframes está no formato 'data'

# %%
novo_df = pd.merge(ibov, precos, how = 'inner', on = 'Date') #Agrupando em um unico dataframe

# %%
novo_df.head()
# Out:
#                 IBOV   VIIA3.SA  OIBR3.SA  SAPR4.SA  IRBR3.SA   EVEN3.SA
# Date
# 2020-12-07  113625.0  17.430000      2.26  4.954013      7.36  11.866971
# 2020-12-08  113571.0  17.700001      2.33  4.925322      7.53  11.811170
# 2020-12-09  112722.0  17.209999      2.45  4.887067      7.26  11.755369
# 2020-12-10  114992.0  17.020000      2.43  4.896631      7.38  11.671668
# 2020-12-11  115323.0  16.820000      2.36  4.925322      7.28  11.671668

# %%
# Normalizando esse novo dataframe que contém o IBOV, todos os ativos e o PL da nossa carteira
precos_normalizado = novo_df/novo_df.iloc[0] #dividir o valor do item pelo primeiro valor do item

# %%
precos_normalizado.tail() #imrpimir os ultimos numeros
# Out:
#                 IBOV  VIIA3.SA  OIBR3.SA  SAPR4.SA  IRBR3.SA  EVEN3.SA
# Date
# 2021-09-30  0.976713  0.442341  0.442478  0.777148  0.642663  0.648017
# 2021-10-01  0.993619  0.475617  0.442478  0.773111  0.671196  0.684252
# 2021-10-04  0.971556  0.441767  0.433628  0.760999  0.658967  0.654758
# 2021-10-05  0.972128  0.450373  0.433628  0.758981  0.656250  0.634534
# 2021-10-06  0.973025  0.465863  0.415929  0.758981  0.657609  0.625265

# %%
# Plot da nossa carteira vs. o IBOV
precos_normalizado.describe()
# Out:
#              IBOV    VIIA3.SA    OIBR3.SA    SAPR4.SA    IRBR3.SA    EVEN3.SA
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     1.053880    0.746162    0.732959    0.838987    0.835803    0.825662
# std      0.046746    0.133070    0.193126    0.062181    0.107519    0.090105
# min      0.957923    0.441767    0.415929    0.754943    0.642663    0.625265
# 25%      1.020964    0.683878    0.539823    0.799372    0.770380    0.775862
# 50%      1.050570    0.729776    0.730088    0.823575    0.826087    0.827586
# 75%      1.082403    0.851979    0.862832    0.856470    0.866848    0.889022
# max      1.150944    1.015491    1.106195    1.040541    1.115489    1.038401

# %%
precos_normalizado['PL Total'] = precos_normalizado.iloc[:].sum(axis = 1)

# %%
#precos_normalizado = precos_normalizado.drop(precos_normalizado.columns[[8]], axis = 1) #excluindo coluna teste

# %%
precos_normalizado.describe()
# Out:
#              IBOV    VIIA3.SA    OIBR3.SA  ...    IRBR3.SA    EVEN3.SA    PL Total
# count  205.000000  205.000000  205.000000  ...  205.000000  205.000000  205.000000
# mean     1.053880    0.746162    0.732959  ...    0.835803    0.825662    5.033453
# std      0.046746    0.133070    0.193126  ...    0.107519    0.090105    0.549844
# min      0.957923    0.441767    0.415929  ...    0.642663    0.625265    3.896672
# 25%      1.020964    0.683878    0.539823  ...    0.770380    0.775862    4.777977
# 50%      1.050570    0.729776    0.730088  ...    0.826087    0.827586    5.047068
# 75%      1.082403    0.851979    0.862832  ...    0.866848    0.889022    5.272849
# max      1.150944    1.015491    1.106195  ...    1.115489    1.038401    6.095703
#
# [8 rows x 7 columns]

# %%
#lista = []
#for i in precos_normalizado:
 # lista.append(i)

#print(lista, '\n')

#IBOV	VIIA3.SA	OIBR3.SA	SAPR4.SA	NGRD3.SA	IRBR3.SA	MOSI3.SA	EVEN3.SA

print('Carteira Murilo Farias x IBOVESPA')
plt.style.use('dark_background')
plt.figure(figsize=(11,16))
#precos_normalizado[lista].plot(figsize = (10,10));

plt.plot(precos_normalizado['IBOV'], label='IBOV')
plt.plot(precos_normalizado['VIIA3.SA'], label='VIIA3')
plt.plot(precos_normalizado['OIBR3.SA'], label='OIBR3')
plt.plot(precos_normalizado['SAPR4.SA'], label='SAPR4')
plt.plot(precos_normalizado['IRBR3.SA'], label='IRBR3')
plt.plot(precos_normalizado['EVEN3.SA'], label='EVEN3')

plt.xlabel('Data')
plt.ylabel('Valor')
plt.legend(loc='best', ncol=3, ) #colocando a legenda no melhor lugar
# Out:
# Carteira Murilo Farias x IBOVESPA

# %%
ibov_cenario = yf.download('^BVSP', start = inicio, end = fim) #trazendo valores do ibov

ibov_cenario
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2020-12-07  113751.0  114531.0  112629.0  113625.0   113625.0   9633900
# 2020-12-08  113590.0  114381.0  112820.0  113571.0   113571.0   8810900
# 2020-12-09  113799.0  114020.0  112567.0  112722.0   112722.0   8431100
# 2020-12-10  113002.0  115262.0  112732.0  114992.0   114992.0  11803600
# 2020-12-11  115128.0  115527.0  113949.0  115323.0   115323.0   8372300
# ...              ...       ...       ...       ...        ...       ...
# 2021-09-30  111117.0  112371.0  110743.0  110979.0   110979.0  13160600
# 2021-10-01  110980.0  113020.0  110980.0  112900.0   112900.0  10779100
# 2021-10-04  112900.0  112900.0  109979.0  110393.0   110393.0  11814200
# 2021-10-05  110397.0  111691.0  110087.0  110458.0   110458.0  10379000
# 2021-10-06  110454.0  110614.0  108180.0  110560.0   110560.0  13279200
#
# [205 rows x 6 columns]

# %%
ibov_cenario['Date'] = ibov_cenario.index

# %%
ibov_teste
# Out:
#                 Open      High       Low  ...  Adj Close    Volume       Date
# Date                                      ...
# 2020-12-07  113751.0  114531.0  112629.0  ...   113625.0   9633900 2020-12-07
# 2020-12-08  113590.0  114381.0  112820.0  ...   113571.0   8810900 2020-12-08
# 2020-12-09  113799.0  114020.0  112567.0  ...   112722.0   8431100 2020-12-09
# 2020-12-10  113002.0  115262.0  112732.0  ...   114992.0  11803600 2020-12-10
# 2020-12-11  115128.0  115527.0  113949.0  ...   115323.0   8372300 2020-12-11
# ...              ...       ...       ...  ...        ...       ...        ...
# 2021-09-30  111117.0  112371.0  110743.0  ...   110979.0  13160600 2021-09-30
# 2021-10-01  110980.0  113020.0  110980.0  ...   112900.0  10779100 2021-10-01
# 2021-10-04  112900.0  112900.0  109979.0  ...   110393.0  11814200 2021-10-04
# 2021-10-05  110397.0  111691.0  110087.0  ...   110458.0  10379000 2021-10-05
# ...

# %%
import pandas as pd   
import plotly.graph_objects as go 
from datetime import datetime

print('IBOVESPA')
apenas_ibov = go.Figure(data = [go.Candlestick(x= ibov_teste['Date'],
                                       open = ibov_teste['Open'],
                                       high = ibov_teste['High'],
                                       low = ibov_teste['Low'],
                                       close = ibov_teste['Adj Close'], increasing_line_color= 'black', decreasing_line_color= 'green')])

apenas_ibov.show()
# Out:
# IBOVESPA
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="775b6821-744e-4831-961c-b12c467d00ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("775b6821-744e-4831-961c-b12c467d00ce")) {
#                     Plotly.newPlot(
#                         '775b6821-744e-4831-961c-b12c467d00ce',
# ...

# %%
VIIA3 = yf.download('VIIA3.SA', start = inicio, end = fim) #trazendo valores do ibov
VIIA3['Date'] = VIIA3.index
VIIA3
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High    Low  ...  Adj Close    Volume       Date
# Date                                     ...
# 2020-12-07  17.700001  17.840000  17.27  ...  17.430000  36992400 2020-12-07
# 2020-12-08  17.410000  18.139999  17.33  ...  17.700001  39730900 2020-12-08
# 2020-12-09  17.750000  17.850000  17.15  ...  17.209999  37509900 2020-12-09
# 2020-12-10  17.299999  17.350000  16.65  ...  17.020000  46566800 2020-12-10
# 2020-12-11  16.900000  17.120001  16.74  ...  16.820000  40625100 2020-12-11
# ...               ...        ...    ...  ...        ...       ...        ...
# 2021-09-30   7.950000   8.020000   7.61  ...   7.710000  45379300 2021-09-30
# 2021-10-01   7.750000   8.450000   7.62  ...   8.290000  46349200 2021-10-01
# 2021-10-04   8.130000   8.130000   7.70  ...   7.700000  32981500 2021-10-04
# 2021-10-05   7.770000   8.100000   7.65  ...   7.850000  27657900 2021-10-05
# ...

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import pandas as pd   
import plotly.graph_objects as go 
from datetime import datetime

lista = ['VIIA3.SA','OIBR3.SA','SAPR4.SA','IRBR3.SA','EVEN3.SA']
resultado = []

for i in lista:
  tudo = yf.download(i, start = inicio, end = fim) #trazendo valores do ibov
  resultado.append(tudo)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
print(resultado)
# Out:
# [                 Open       High    Low      Close  Adj Close    Volume
# Date
# 2020-12-07  17.700001  17.840000  17.27  17.430000  17.430000  36992400
# 2020-12-08  17.410000  18.139999  17.33  17.700001  17.700001  39730900
# 2020-12-09  17.750000  17.850000  17.15  17.209999  17.209999  37509900
# 2020-12-10  17.299999  17.350000  16.65  17.020000  17.020000  46566800
# 2020-12-11  16.900000  17.120001  16.74  16.820000  16.820000  40625100
# ...               ...        ...    ...        ...        ...       ...
# 2021-09-30   7.950000   8.020000   7.61   7.710000   7.710000  45379300
# 2021-10-01   7.750000   8.450000   7.62   8.290000   8.290000  46349200
# 2021-10-04   8.130000   8.130000   7.70   7.700000   7.700000  32981500
# 2021-10-05   7.770000   8.100000   7.65   7.850000   7.850000  27657900
# 2021-10-06   7.610000   8.130000   7.43   8.120000   8.120000  50481900
#
# [205 rows x 6 columns],             Open  High   Low  Close  Adj Close     Volume
# Date
# ...

# %%
#resultado_1 = resultado[0] #viia3

resultado_a = yf.download('VIIA3.SA', start = inicio, end = fim) #trazendo valores do ibov
resultado_a['Data'] = resultado_1.index
resultado_a = resultado_1

resultado_b = yf.download('OIBR3.SA', start = inicio, end = fim) #trazendo valores do ibov
resultado_b['Data'] = resultado_2.index
resultado_b = resultado_2

resultado_c = yf.download('SAPR4.SA', start = inicio, end = fim) #trazendo valores do ibov
resultado_c['Data'] = resultado_3.index
resultado_c = resultado_3

#resultado_d = yf.download('NGRD3.SA', start = inicio, end = fim) #trazendo valores do ibov
#resultado_d['Data'] = resultado_4.index
#resultado_d = resultado_4

resultado_e = yf.download('IRBR3.SA', start = inicio, end = fim) #trazendo valores do ibov
resultado_e['Data'] = resultado_5.index
resultado_e = resultado_5

#resultado_f = yf.download('MOSI3.SA', start = inicio, end = fim) #trazendo valores do ibov
#resultado_f['Data'] = resultado_6.index
#resultado_f = resultado_6

resultado_g = yf.download('EVEN3.SA', start = inicio, end = fim) #trazendo valores do ibov
resultado_g['Data'] = resultado_7.index
resultado_g = resultado_7

print(resultado_g)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close   Volume       Data
# Date
# 2020-12-07  12.80  12.93  12.53  12.76  11.866971   998400 2020-12-07
# 2020-12-08  12.75  12.97  12.56  12.70  11.811170   599800 2020-12-08
# 2020-12-09  12.77  13.15  12.44  12.64  11.755369  2108400 2020-12-09
# 2020-12-10  12.64  12.81  12.07  12.55  11.671668  1851100 2020-12-10
# 2020-12-11  12.59  12.73  12.33  12.55  11.671668  1438700 2020-12-11
# ...           ...    ...    ...    ...        ...      ...        ...
# 2021-09-30   7.65   7.82   7.59   7.69   7.690000  1449100 2021-09-30
# ...

# %%
import pandas as pd   
import plotly.graph_objects as go 
from datetime import datetime

#lista = ['VIIA3.SA','OIBR3.SA','SAPR4.SA','NGRD3.SA','IRBR3.SA','MOSI3.SA','EVEN3.SA']

print('CENARIO Via Varejo')
cenario_a = go.Figure(data = [go.Candlestick(x= resultado_a['Data'],
                                       open = resultado_a['Open'],
                                       high = resultado_a['High'],
                                       low = resultado_a['Low'],
                                       close = resultado_a['Adj Close'],increasing_line_color= 'brown', decreasing_line_color= 'green')])
cenario_a.show()

print('CENARIO Oi')
cenario_b = go.Figure(data = [go.Candlestick(x= resultado_b['Data'],
                                       open = resultado_b['Open'],
                                       high = resultado_b['High'],
                                       low = resultado_b['Low'],
                                       close = resultado_b['Adj Close'],increasing_line_color= 'blue', decreasing_line_color= 'green')])
cenario_b.show()

print('CENARIO Sanepar')
cenario_c = go.Figure(data = [go.Candlestick(x= resultado_c['Data'],
                                       open = resultado_c['Open'],
                                       high = resultado_c['High'],
                                       low = resultado_c['Low'],
                                       close = resultado_c['Adj Close'],increasing_line_color= 'red', decreasing_line_color= 'green')])
cenario_c.show()

print('CENARIO IRBR')
cenario_e = go.Figure(data = [go.Candlestick(x= resultado_e['Data'],
                                       open = resultado_e['Open'],
                                       high = resultado_e['High'],
                                       low = resultado_e['Low'],
                                       close = resultado_e['Adj Close'],increasing_line_color= 'purple', decreasing_line_color= 'green')])
cenario_e.show()

print('CENARIO EVEN3')
cenario_g = go.Figure(data = [go.Candlestick(x= resultado_g['Data'],
                                       open = resultado_g['Open'],
                                       high = resultado_g['High'],
                                       low = resultado_g['Low'],
                                       close = resultado_g['Adj Close'],increasing_line_color= 'orange', decreasing_line_color= 'green')])
cenario_g.show()
# Out:
# CENARIO VIIA3
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="87949407-150c-4827-8a21-7d24a321ec3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("87949407-150c-4827-8a21-7d24a321ec3a")) {
#                     Plotly.newPlot(
#                         '87949407-150c-4827-8a21-7d24a321ec3a',
# ...

# %%
precos
# Out:
#              VIIA3.SA  OIBR3.SA  SAPR4.SA  ...  IRBR3.SA  MOSI3.SA   EVEN3.SA
# Date                                       ...
# 2020-12-07  17.430000      2.26  4.954013  ...      7.36       NaN  11.866970
# 2020-12-08  17.700001      2.33  4.925322  ...      7.53       NaN  11.811170
# 2020-12-09  17.209999      2.45  4.887067  ...      7.26       NaN  11.755369
# 2020-12-10  17.020000      2.43  4.896631  ...      7.38       NaN  11.671668
# 2020-12-11  16.820000      2.36  4.925322  ...      7.28       NaN  11.671668
# ...               ...       ...       ...  ...       ...       ...        ...
# 2021-09-30   7.710000      1.00  3.850000  ...      4.73     11.60   7.690000
# 2021-10-01   8.290000      1.00  3.830000  ...      4.94     12.62   8.120000
# 2021-10-04   7.700000      0.98  3.770000  ...      4.85     13.32   7.770000
# 2021-10-05   7.850000      0.98  3.760000  ...      4.83     12.05   7.530000
# ...

# %% [markdown]
# ## 3. Simulação de uma carteira fictícia

# %% [markdown]
# Criando um dicionário com as alocações que vamos fazer para cada ativo na nossa carteira

# %%
compras = {'PETR4.SA': 1000, 'VALE3.SA': 700, 'WEGE3.SA': 1500, 
           'RADL3.SA': 700, 'OIBR3.SA': 200, 'KNRI11.SA': 700, 'FLMA11.SA': 700, 'BOVA11.SA':1500,
           'SMAL11.SA': 1500, 'AAPL34.SA': 2000, 'IVVB11.SA': 1500, 
           'ETH-BRL': 200}
           
compras_df = pd.Series(data=compras, index=list(compras.keys()))

# %% [markdown]
# Qual o valor total da nossa carteira?

# %%
sum(compras.values())
# Out:
# 12200

# %% [markdown]
# Obtendo preços dos ativos no primeiro dia do investimento

# %%
primeiro = precos.iloc[0]

# %% [markdown]
# Quantidade de papéis comprados de cada ativo

# %%
qtd_acoes = compras_df/primeiro

# %% [markdown]
# Criando um dataframe que contém a posição diária de cada ativo

# %%
PL = precos*qtd_acoes

# %%
PL.head(3)
# Out:
#             AAPL34.SA  BOVA11.SA  ETH-BRL  ...  VIIA3.SA  WEGE3.SA    PL Total
# Date                                       ...
# 2020-12-07        NaN        NaN      NaN  ...       NaN       NaN  200.000000
# 2020-12-08        NaN        NaN      NaN  ...       NaN       NaN  206.194684
# 2020-12-09        NaN        NaN      NaN  ...       NaN       NaN  216.814164
#
# [3 rows x 19 columns]

# %%
PL.tail()
# Out:
#             AAPL34.SA  BOVA11.SA  ETH-BRL  ...  VALE3.SA  VIIA3.SA  WEGE3.SA
# Date                                       ...
# 2021-09-30        NaN        NaN      NaN  ...       NaN       NaN       NaN
# 2021-10-01        NaN        NaN      NaN  ...       NaN       NaN       NaN
# 2021-10-04        NaN        NaN      NaN  ...       NaN       NaN       NaN
# 2021-10-05        NaN        NaN      NaN  ...       NaN       NaN       NaN
# 2021-10-06        NaN        NaN      NaN  ...       NaN       NaN       NaN
#
# [5 rows x 18 columns]

# %% [markdown]
# Criando uma coluna que contém a posição consolidada da nossa carteira diariamente

# %%
PL['PL Total'] = PL.iloc[:].sum(axis = 1)

# %%
PL.head()
# Out:
#             AAPL34.SA  BOVA11.SA  ETH-BRL  ...  VIIA3.SA  WEGE3.SA    PL Total
# Date                                       ...
# 2020-12-07        NaN        NaN      NaN  ...       NaN       NaN  200.000000
# 2020-12-08        NaN        NaN      NaN  ...       NaN       NaN  206.194684
# 2020-12-09        NaN        NaN      NaN  ...       NaN       NaN  216.814164
# 2020-12-10        NaN        NaN      NaN  ...       NaN       NaN  215.044255
# 2020-12-11        NaN        NaN      NaN  ...       NaN       NaN  208.849549
#
# [5 rows x 19 columns]

# %%
PL.tail()
# Out:
#             AAPL34.SA  BOVA11.SA  ETH-BRL  ...  VIIA3.SA  WEGE3.SA   PL Total
# Date                                       ...
# 2021-09-30        NaN        NaN      NaN  ...       NaN       NaN  88.495576
# 2021-10-01        NaN        NaN      NaN  ...       NaN       NaN  88.495576
# 2021-10-04        NaN        NaN      NaN  ...       NaN       NaN  86.725666
# 2021-10-05        NaN        NaN      NaN  ...       NaN       NaN  86.725666
# 2021-10-06        NaN        NaN      NaN  ...       NaN       NaN  83.185841
#
# [5 rows x 19 columns]
